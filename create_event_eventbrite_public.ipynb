# %% [markdown]
# <a href="https://colab.research.google.com/github/kgautam2103/Eventbrite_automation_libraray_public/blob/main/create_event_eventbrite_public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# when you run this code, you will get a link below
#Follow the link, copy the code, paste it in the box and then press Enter on the keyboard.
#This will authenticate you and will allow you to interact with Google Sheets and other Google apps in your notebook.
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
import pandas as pd
import requests
import json
from datetime import datetime

#define global variables
#auth token for Eventbrite account admin user
auth_token = ''
prod_url = 'https://www.eventbriteapi.com/v3/'
prod_proxy_url= 'https://private-anon-3ec5fc757f-eventbriteapiv3public.apiary-proxy.com/v3/'
mock_url='https://private-anon-86d996fd56-eventbriteapiv3public.apiary-mock.com/v3/'
org = 'organizations/'
venues= '/venues/'
events= 'events/'
copy= '/copy/'
publish= '/publish/'
#start_date='2021-08-24T00:45:00Z'
#end_date='2021-08-24T01:45:00Z'
start_date = input('enter the start date as 2021-08-24T00:45:00Z : ')
end_date = input('enter the end date as 2021-08-24T00:45:00Z : ')
current_ts = datetime.now().strftime('%Y%m%d%H%M%S')
output_sheet = current_ts+'_event_output'
counter=1

authorization = 'Bearer '+auth_token
headers = {
        'Authorization': authorization,
        'Content-Type': 'application/json'
    }

wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/1ryMfzfy6u2N0V4qg1B-xzRYTaNcs_e4o-DBddru1raI/edit#gid=0')

# create and Open our new sheet and add some data.
sh = gc.create(output_sheet)
output_sheet = gc.open(output_sheet).sheet1

output_sheet.insert_row(['event_id','is_published','venue_id','city','region','postal_code','country','org_id','venue_error','event_error'],1)

sheet_name = input('enter the name of input sheet : ')
input_sheet = wb.worksheet(sheet_name)
inputdata = input_sheet.get_all_values()
inputdata_df = pd.DataFrame(inputdata, columns=['name',	'capacity','address1','address2','city','region',
                                                'postal_code','country','timezone','org_id','sample_event_id','replace_city'])
inputdata_df = inputdata_df.drop(inputdata_df.index[0])

for index,row in inputdata_df.iterrows():
  counter = counter+1
  venue_id=""
  venue_error=""
  event_id = ""
  event_error = ""
  copy_error = ""
  update_error = ""
  publish_error = ""
  is_published = False
  cell_value_list = []
  address_details={
        "address_1": str(row['address1']),
        "address_2": str(row['address2']),
        "city": str(row['city']),
        "region": str(row['region']),
        "postal_code": str(row['postal_code']),
        "country": str(row['country'])
    }

  venue_details = {
        "name": str(row['name']),
        "capacity": str(row['capacity']),
        "address":address_details
        }

  final_venue_body = {
        "venue": venue_details
    }

  organization_id = str(row['org_id']).strip()
  venue_url = prod_url + org + organization_id + venues  
  venue_values = json.dumps(final_venue_body)  

  venue_response = requests.post(venue_url,data=venue_values,headers=headers)
  venue_status = venue_response.status_code
  
  if venue_status == 200:
    venue_id = str(venue_response.json()['id'])
  else:
    venue_error = venue_response.text

  print("venue_id "+venue_id)
  print("venue_status "+str(venue_status))
  print("venue_error "+venue_error)

  city_name = str(row['city'])
  sample_event_id = str(row['sample_event_id'])
  retrieve_event_url = prod_url+events+sample_event_id
  retrieve_response = requests.get(retrieve_event_url,headers=headers)

  event_name = str(retrieve_response.json()['name']['text'])
  event_desc = str(retrieve_response.json()['description']['text'])
  new_event_name = event_name.replace(str(row['replace_city']),city_name)
  new_event_desc = event_desc.replace(str(row['replace_city']),city_name)

  copy_event_url = prod_url+events+sample_event_id+copy
  copy_response = requests.post(copy_event_url,headers=headers)
  copy_status = copy_response.status_code

  if copy_status == 200:
    event_id = str(copy_response.json()['id'])
  else:
    copy_error = copy_response.text
  
  print("event_id "+event_id)
  print("copy_status "+str(copy_status))
  print("copy_error "+copy_error)

  update_event_url = prod_url+events+event_id+"/"
  publish_event_url = prod_url+events+event_id+publish
  timezone = str(row['timezone']).strip()

  print(new_event_name)

  update_request_body = {"event": {"name": {
        "html": new_event_name},"description": {
        "html": new_event_desc},"venue_id": venue_id,
          "start": {"timezone": timezone, "utc": start_date},
          "end": {"timezone": timezone, "utc": end_date}
      }
      }

  update_event_values = json.dumps(update_request_body)
  print(update_event_values)

  update_response = requests.post(update_event_url, data=update_event_values, headers=headers)
  update_status = update_response.status_code

  print(update_response.json())
  print("update_status "+str(update_status))

  if update_status == 200:
    publish_response = requests.post(publish_event_url,headers=headers)
    publish_status = publish_response.status_code
    if publish_status == 200:
      is_published=True
    else:
      publish_error = publish_response.text
  else:
    update_error = update_response.text

  print(is_published)  
  event_error = copy_error+update_error+publish_error
  print("event_error "+event_error)
  cell_value_list = [event_id,is_published,venue_id,city_name,str(row['region']),str(row['postal_code']),str(row['country']),organization_id,venue_error,event_error]
  output_sheet.insert_row(cell_value_list,counter)
# Out:
# enter the start date as 2021-08-24T00:45:00Z : 2022-03-06T01:45:00Z
# enter the end date as 2021-08-24T00:45:00Z : 2022-03-06T03:00:00Z
# enter the name of input sheet : inputdata
# venue_id 83529149
# venue_status 200
# venue_error
# event_id 268177154087
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Birmingham! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Birmingham! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529149", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Birmingham! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Birmingham! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-birmingham-21-day-meditation-tickets-268177154087', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:26:22Z', 'changed': '2022-02-12T19:26:25Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228961639', 'organizer_id': '33189524691', 'venue_id': '83529149', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177154087', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177154087/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961639%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=746bfb59f5126b9c42d7ee077cdbc99c', 'width': 1023, 'height': 674}, 'id': '228961639', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961639%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=43b71b8b4c5473983cc99434e9ea4f96', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529199
# venue_status 200
# venue_error
# event_id 268177194207
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Leeds! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Leeds! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529199", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Leeds! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Leeds! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-leeds-21-day-meditation-tickets-268177194207', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:26:33Z', 'changed': '2022-02-12T19:26:37Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228961699', 'organizer_id': '33189524691', 'venue_id': '83529199', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177194207', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177194207/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961699%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=e177b8b145f79e5ddbbc2749cc9c7322', 'width': 1023, 'height': 674}, 'id': '228961699', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961699%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=18ef30756f21c9f9f7b8fc615bc46a3d', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529249
# venue_status 200
# venue_error
# event_id 268177234327
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Glasgow! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Glasgow! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529249", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Glasgow! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Glasgow! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-glasgow-21-day-meditation-tickets-268177234327', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:26:44Z', 'changed': '2022-02-12T19:26:47Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228961739', 'organizer_id': '33189524691', 'venue_id': '83529249', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177234327', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177234327/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961739%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=29e925101343dbc9a40c3b5613850477', 'width': 1023, 'height': 674}, 'id': '228961739', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961739%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=dd2802b6638655316c5dcd4fc9ed58ce', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529279
# venue_status 200
# venue_error
# event_id 268177264417
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Manchester! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Manchester! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529279", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Manchester! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Manchester! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-manchester-21-day-meditation-tickets-268177264417', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:26:55Z', 'changed': '2022-02-12T19:26:58Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228961789', 'organizer_id': '33189524691', 'venue_id': '83529279', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177264417', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177264417/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961789%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=24bfc489b102895c3202cd35898d373d', 'width': 1023, 'height': 674}, 'id': '228961789', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961789%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=79159da4eb3e8e295ed36f3fc40dc6b4', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529309
# venue_status 200
# venue_error
# event_id 268177284477
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Edinburgh! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Edinburgh! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529309", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Edinburgh! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Edinburgh! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-edinburgh-21-day-meditation-tickets-268177284477', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:27:06Z', 'changed': '2022-02-12T19:27:09Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228961859', 'organizer_id': '33189524691', 'venue_id': '83529309', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177284477', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177284477/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961859%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=134388739c7199c937cc7e2b31787795', 'width': 1023, 'height': 674}, 'id': '228961859', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961859%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=8352754a52fbaa8a6887b87014dceab8', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529329
# venue_status 200
# venue_error
# event_id 268177294507
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Liverpool! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Liverpool! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529329", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Liverpool! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Liverpool! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-liverpool-21-day-meditation-tickets-268177294507', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:27:17Z', 'changed': '2022-02-12T19:27:20Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228961959', 'organizer_id': '33189524691', 'venue_id': '83529329', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177294507', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177294507/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961959%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=146cca764b599eb693b10360f13aa34f', 'width': 1023, 'height': 674}, 'id': '228961959', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228961959%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=1b6978b56bd85a68d94f9b8bd210e579', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529349
# venue_status 200
# venue_error
# event_id 268177304537
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Cardiff! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Cardiff! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529349", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Cardiff! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Cardiff! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-cardiff-21-day-meditation-tickets-268177304537', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:27:28Z', 'changed': '2022-02-12T19:27:30Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962039', 'organizer_id': '33189524691', 'venue_id': '83529349', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177304537', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177304537/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962039%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=d41b70b0ba7d945169f9aa15f8610bb2', 'width': 1023, 'height': 674}, 'id': '228962039', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962039%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=488f240f4bd3e61aa888a88537973a8c', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529389
# venue_status 200
# venue_error
# event_id 268177334627
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Leicester! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Leicester! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529389", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Leicester! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Leicester! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-leicester-21-day-meditation-tickets-268177334627', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:27:39Z', 'changed': '2022-02-12T19:27:41Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962089', 'organizer_id': '33189524691', 'venue_id': '83529389', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177334627', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177334627/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962089%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=4a921051d237be84c2059fda5778944b', 'width': 1023, 'height': 674}, 'id': '228962089', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962089%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=cac671ca095a934575a96285ada48fc2', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529409
# venue_status 200
# venue_error
# event_id 268177354687
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Nottingham! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Nottingham! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529409", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Nottingham! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Nottingham! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-nottingham-21-day-meditation-tickets-268177354687', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:27:49Z', 'changed': '2022-02-12T19:27:52Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962129', 'organizer_id': '33189524691', 'venue_id': '83529409', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177354687', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177354687/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962129%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=34dedecb7ab90f41a64a9c608731835e', 'width': 1023, 'height': 674}, 'id': '228962129', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962129%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=045008adfc4ceb67345a8fe6cb1f0bac', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529429
# venue_status 200
# venue_error
# event_id 268177364717
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Coventry! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Coventry! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529429", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Coventry! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Coventry! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-coventry-21-day-meditation-tickets-268177364717', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:28:00Z', 'changed': '2022-02-12T19:28:03Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962179', 'organizer_id': '33189524691', 'venue_id': '83529429', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177364717', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177364717/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962179%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=bc3e3031b1a4fe426309df6dc07a1069', 'width': 1023, 'height': 674}, 'id': '228962179', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962179%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=3adb264857197e6baf4e44994f24242f', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529449
# venue_status 200
# venue_error
# event_id 268177384777
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Southampton! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Southampton! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529449", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Southampton! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Southampton! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-southampton-21-day-meditation-tickets-268177384777', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:28:12Z', 'changed': '2022-02-12T19:28:14Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962259', 'organizer_id': '33189524691', 'venue_id': '83529449', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177384777', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177384777/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962259%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=a93a99a2bfaab29b5af523362b16a778', 'width': 1023, 'height': 674}, 'id': '228962259', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962259%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=346d5c0164dd404d50cd060beb209dcb', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529479
# venue_status 200
# venue_error
# event_id 268177414867
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Wolverhampton! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Wolverhampton! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529479", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Wolverhampton! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Wolverhampton! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-wolverhampton-21-day-meditation-tickets-268177414867', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:28:22Z', 'changed': '2022-02-12T19:28:25Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962309', 'organizer_id': '33189524691', 'venue_id': '83529479', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177414867', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177414867/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962309%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=8f56c2c1444484b4df7f36136dd4d7b6', 'width': 1023, 'height': 674}, 'id': '228962309', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962309%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=e69e6f60fc167ab7bb4eadc729663979', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529509
# venue_status 200
# venue_error
# event_id 268177424897
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Derby! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Derby! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529509", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Derby! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Derby! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-derby-21-day-meditation-tickets-268177424897', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:28:34Z', 'changed': '2022-02-12T19:28:36Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962339', 'organizer_id': '33189524691', 'venue_id': '83529509', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177424897', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177424897/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962339%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=24f05477f1567d013bc44e7398f64fc7', 'width': 1023, 'height': 674}, 'id': '228962339', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962339%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=5d22ad43a355e96a2866fd1c11eca0a4', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529529
# venue_status 200
# venue_error
# event_id 268177434927
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Aberdeen! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Aberdeen! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529529", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Aberdeen! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Aberdeen! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-aberdeen-21-day-meditation-tickets-268177434927', 'start': {'timezone': 'Europe/London', 'local': '2022-03-06T01:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Europe/London', 'local': '2022-03-06T03:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T19:28:44Z', 'changed': '2022-02-12T19:28:47Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228962389', 'organizer_id': '33189524691', 'venue_id': '83529529', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268177434927', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268177434927/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962389%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=ba21dadefe6ae191f2baec6de8d5464f', 'width': 1023, 'height': 674}, 'id': '228962389', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228962389%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=98ddf6cac59383a6dac24fd8c2bb6c03', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83529549
# venue_status 200
# venue_error
# event_id 268177454987
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Plymouth! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Plymouth! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83529549", "start": {"timezone": "Europe/London", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Europe/London", "utc": "2022-03-06T03:00:00Z"}}}
# ...
# {'name': {'text': 'I want spiritual awakening, just not alone in Melbourne! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Melbourne! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-melbourne-21-day-meditation-tickets-268201135817', 'start': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T12:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T14:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T20:05:25Z', 'changed': '2022-02-12T20:05:27Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228974039', 'organizer_id': '33189524691', 'venue_id': '83535879', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268201135817', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268201135817/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974039%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=573798dfce7df5f653062036a69d4eb9', 'width': 1023, 'height': 674}, 'id': '228974039', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974039%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=dd7069c150cafd57277fe5669a323b0d', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83535929
# venue_status 200
# venue_error
# event_id 268201797797
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Geelong! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Geelong! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83535929", "start": {"timezone": "Australia/Sydney", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Australia/Sydney", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Geelong! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Geelong! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-geelong-21-day-meditation-tickets-268201797797', 'start': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T12:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T14:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T20:05:35Z', 'changed': '2022-02-12T20:05:38Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228974099', 'organizer_id': '33189524691', 'venue_id': '83535929', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268201797797', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268201797797/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974099%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=e424c10b3285ec4a9c8a1796165afe74', 'width': 1023, 'height': 674}, 'id': '228974099', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974099%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=7bddad000a7ad004096d5d815e868b35', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83535979
# venue_status 200
# venue_error
# event_id 268201837917
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Warrnambool! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Warrnambool! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83535979", "start": {"timezone": "Australia/Sydney", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Australia/Sydney", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Warrnambool! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Warrnambool! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-warrnambool-21-day-meditation-tickets-268201837917', 'start': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T12:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T14:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T20:05:46Z', 'changed': '2022-02-12T20:05:49Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228974189', 'organizer_id': '33189524691', 'venue_id': '83535979', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268201837917', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268201837917/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974189%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=f1cf9b3a4620785aa591024b43a2c921', 'width': 1023, 'height': 674}, 'id': '228974189', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974189%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=dcb54ce356fa9e0226c28063ecef8058', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83536019
# venue_status 200
# venue_error
# event_id 268201888067
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Shepparton! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Shepparton! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83536019", "start": {"timezone": "Australia/Sydney", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Australia/Sydney", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Shepparton! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Shepparton! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-shepparton-21-day-meditation-tickets-268201888067', 'start': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T12:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T14:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T20:05:56Z', 'changed': '2022-02-12T20:05:59Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228974239', 'organizer_id': '33189524691', 'venue_id': '83536019', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268201888067', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268201888067/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974239%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=e6676039407d20636c247c1174ac4a98', 'width': 1023, 'height': 674}, 'id': '228974239', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974239%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=673be69db1d1b0381ad2ecbaad4c238a', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error
# venue_id 83536089
# venue_status 200
# venue_error
# event_id 268201938217
# copy_status 200
# copy_error
# I want spiritual awakening, just not alone in Bairnsdale! 21 Day Meditation
# {"event": {"name": {"html": "I want spiritual awakening, just not alone in Bairnsdale! 21 Day Meditation"}, "description": {"html": "Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy."}, "venue_id": "83536089", "start": {"timezone": "Australia/Sydney", "utc": "2022-03-06T01:45:00Z"}, "end": {"timezone": "Australia/Sydney", "utc": "2022-03-06T03:00:00Z"}}}
# {'name': {'text': 'I want spiritual awakening, just not alone in Bairnsdale! 21 Day Meditation', 'html': 'I want spiritual awakening, just not alone in Bairnsdale! 21 Day Meditation'}, 'description': {'text': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'html': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.'}, 'url': 'https://www.eventbrite.com/e/i-want-spiritual-awakening-just-not-alone-in-bairnsdale-21-day-meditation-tickets-268201938217', 'start': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T12:45:00', 'utc': '2022-03-06T01:45:00Z'}, 'end': {'timezone': 'Australia/Sydney', 'local': '2022-03-06T14:00:00', 'utc': '2022-03-06T03:00:00Z'}, 'organization_id': '532998122497', 'created': '2022-02-12T20:06:06Z', 'changed': '2022-02-12T20:06:09Z', 'capacity': 7, 'capacity_is_custom': False, 'status': 'draft', 'currency': 'USD', 'listed': True, 'shareable': True, 'invite_only': False, 'online_event': False, 'show_remaining': True, 'tx_time_limit': 1200, 'hide_start_date': False, 'hide_end_date': False, 'locale': 'en_US', 'is_locked': False, 'privacy_setting': 'unlocked', 'is_series': False, 'is_series_parent': False, 'inventory_type': 'limited', 'is_reserved_seating': False, 'show_pick_a_seat': False, 'show_seatmap_thumbnail': False, 'show_colors_in_seatmap_thumbnail': False, 'source': 'coyote', 'is_free': True, 'version': None, 'summary': 'Spiritual Awakening through meditation. 21 days of guided meditation. Raise consciousness to higher dimension and activate inner energy.', 'facebook_event_id': None, 'logo_id': '228974289', 'organizer_id': '33189524691', 'venue_id': '83536089', 'category_id': '114', 'subcategory_id': '14009', 'format_id': '9', 'id': '268201938217', 'resource_uri': 'https://www.eventbriteapi.com/v3/events/268201938217/', 'is_externally_ticketed': False, 'logo': {'crop_mask': {'top_left': {'x': 0, 'y': 21}, 'width': 1022, 'height': 511}, 'original': {'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974289%2F647919780083%2F1%2Foriginal.20220210-072956?auto=format%2Ccompress&q=75&sharp=10&s=99b275cfb9ecde13a7eefaebee9c2863', 'width': 1023, 'height': 674}, 'id': '228974289', 'url': 'https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F228974289%2F647919780083%2F1%2Foriginal.20220210-072956?h=200&w=450&auto=format%2Ccompress&q=75&sharp=10&rect=0%2C21%2C1022%2C511&s=6928e72034c53122249b50181851a089', 'aspect_ratio': '2', 'edge_color': '#3b5f80', 'edge_color_set': True}}
# update_status 200
# True
# event_error

# %%
inputdata_df
